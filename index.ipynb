# %% [markdown]
# # Accessing Data within Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, we'll look at a dataset which contains information on World Cup matches. Let's use the pandas commands learned in the previous lesson to learn more about our data!

# %% [markdown]
# ## Objectives
#
# You will be able to:
#
# - Use pandas methods and attributes to access information about a dataset
# - Index pandas dataframes with .loc, .iloc, and column names
# - Use a boolean mask to index pandas series and dataframes

# %% [markdown]
# ## Load the Data

# %% [markdown]
# Load the file `'WorldCupMatches.csv'` as a DataFrame in pandas.

# %%
# Replace None with appropriate code

# Import pandas using the standard alias
import pandas as pd

# Load 'WorldCupMatches.csv' as a DataFrame
df = pd.read_csv("WorldCupMatches.csv")

# %% [markdown]
# ## Common Methods and Attributes

# %% [markdown]
# Use the correct method to display the **first 7 rows** of the dataset.

# %%
# Your code here
df[:7]
# Out:
#      Year              Datetime    Stage         Stadium         City  \
# 0  1930.0  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930.0  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930.0  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930.0  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930.0  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930.0  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
# 6  1930.0  17 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France              4.0              1.0         Mexico
# 1            USA              3.0              0.0        Belgium
# 2     Yugoslavia              2.0              1.0         Brazil
# 3        Romania              3.0              1.0           Peru
# 4      Argentina              1.0              0.0         France
# 5          Chile              3.0              0.0         Mexico
# 6     Yugoslavia              4.0              0.0        Bolivia
#
#   Win conditions  ...  Half-time Home Goals  Half-time Away Goals  \
# 0                 ...                   3.0                   0.0
# 1                 ...                   2.0                   0.0
# 2                 ...                   2.0                   0.0
# 3                 ...                   1.0                   0.0
# 4                 ...                   0.0                   0.0
# 5                 ...                   1.0                   0.0
# 6                 ...                   0.0                   0.0
#
#                     Referee               Assistant 1  \
# 0    LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1         MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2       TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3     WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4       REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
# 5     CRISTOPHE Henry (BEL)   APHESTEGUY Martin (URU)
# 6  MATEUCCI Francisco (URU)    LOMBARDI Domingo (URU)
#
#                   Assistant 2 RoundID  MatchID  Home Team Initials  \
# 0         REGO Gilberto (BRA)   201.0   1096.0                 FRA
# 1       WARNKEN Alberto (CHI)   201.0   1090.0                 USA
# 2         BALWAY Thomas (FRA)   201.0   1093.0                 YUG
# 3    MATEUCCI Francisco (URU)   201.0   1098.0                 ROU
# 4  RADULESCU Constantin (ROU)   201.0   1085.0                 ARG
# 5         LANGENUS Jean (BEL)   201.0   1095.0                 CHI
# 6       WARNKEN Alberto (CHI)   201.0   1092.0                 YUG
#
#   Away Team Initials Half-Time-Goals
# 0                MEX             3.0
# 1                BEL             2.0
# 2                BRA             2.0
# 3                PER             1.0
# 4                FRA             0.0
# 5                MEX             1.0
# 6                BOL             0.0
#
# [7 rows x 21 columns]

# %% [markdown]
# Display the **last 3 rows** of the dataset.

# %%
# Your code here
df[-3:]
# Out:
#      Year              Datetime                     Stage  \
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                       Win conditions  \
# 849                0      Argentina  Argentina win on penalties (2 - 4)
# 850                3    Netherlands
# 851                0      Argentina        Germany win after extra time
#
#      Attendance  Half-time Home Goals  Half-time Away Goals  \
# 849     63267.0                     0                     0
# 850     68034.0                     0                     2
# 851     74738.0                     0                     0
#
#                    Referee            Assistant 1              Assistant 2  \
# 849     C�neyt �AKIR (TUR)   DURAN Bahattin (TUR)        ONGUN Tarik (TUR)
# 850  HAIMOUDI Djamel (ALG)   ACHIK Redouane (MAR)  ETCHIALI Abdelhak (ALG)
# 851   Nicola RIZZOLI (ITA)  Renato FAVERANI (ITA)     Andrea STEFANI (ITA)
#
#      RoundID    MatchID Home Team Initials Away Team Initials
# 849   255955  300186490                NED                ARG
# 850   255957  300186502                BRA                NED
# 851   255959  300186501                GER                ARG

# %% [markdown]
# Get a concise summary of the data using `.info()`.

# %%
# Your code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  852 non-null    int64
#  1   Datetime              852 non-null    object
#  2   Stage                 852 non-null    object
#  3   Stadium               852 non-null    object
#  4   City                  852 non-null    object
#  5   Home Team Name        852 non-null    object
#  6   Home Team Goals       852 non-null    int64
#  7   Away Team Goals       852 non-null    int64
#  8   Away Team Name        852 non-null    object
#  9   Win conditions        852 non-null    object
#  10  Attendance            850 non-null    float64
#  11  Half-time Home Goals  852 non-null    int64
#  12  Half-time Away Goals  852 non-null    int64
#  13  Referee               852 non-null    object
#  14  Assistant 1           852 non-null    object
#  15  Assistant 2           852 non-null    object
#  16  RoundID               852 non-null    int64
#  17  MatchID               852 non-null    int64
#  18  Home Team Initials    852 non-null    object
#  19  Away Team Initials    852 non-null    object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 133.3+ KB

# %% [markdown]
# Obtain a tuple representing the **number of rows and number of columns**.

# %%
# Your code here
t = df.shape
t
# Out:
# (852, 20)

# %% [markdown]
# Use the appropriate attribute to get the **column names**.

# %%
# Your code here
names = list(df.columns)
names
# Out:
# ['Year',
#  'Datetime',
#  'Stage',
#  'Stadium',
#  'City',
#  'Home Team Name',
#  'Home Team Goals',
#  'Away Team Goals',
#  'Away Team Name',
#  'Win conditions',
#  'Attendance',
#  'Half-time Home Goals',
#  'Half-time Away Goals',
#  'Referee',
#  'Assistant 1',
#  'Assistant 2',
#  'RoundID',
#  'MatchID',
#  'Home Team Initials',
#  'Away Team Initials']

# %% [markdown]
# ## Selecting DataFrame Information

# %% [markdown]
# When looking at the DataFrame's `.head()` and `.tail()`, you might have noticed that the games are structured chronologically in the DataFrame.
#
# Use the right selection method to display all the information from the 3rd to the 5th game (i.e. **select rows 3 through 5 inclusive**).

# %%
# Your code here
three_to_five = df.iloc[3:6]
three_to_five
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
#
#                  Referee              Assistant 1                 Assistant 2  \
# 3  WARNKEN Alberto (CHI)      LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)
# 4    REGO Gilberto (BRA)     SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)
# 5  CRISTOPHE Henry (BEL)  APHESTEGUY Martin (URU)         LANGENUS Jean (BEL)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# 3      201     1098                ROU                PER
# 4      201     1085                ARG                FRA
# 5      201     1095                CHI                MEX

# %% [markdown]
# Now, display the info from **game 5-9** (inclusive), but **only the `"Home Team Name"` and the `"Away Team Name"` columns**.

# %%
# Your code here
df.iloc[5:10, [5,8]]
# Out:
#   Home Team Name Away Team Name
# 5          Chile         Mexico
# 6     Yugoslavia        Bolivia
# 7            USA       Paraguay
# 8        Uruguay           Peru
# 9          Chile         France

# %% [markdown]
# Next, we'd like the information on all the games played in **Group 3** for the **1950** World Cup.

# %% [markdown]
# Hint: You can combine conditions like this:
#
# `df[(condition1) | (condition2)]`  -> Returns rows where either condition is true
#
# `df[(condition1) & (condition2)]`  -> Returns rows where both conditions are true

# %%
# Your code here
df.loc[((df["Stage"] == "Group 3") & (df["Year"] == 1950))]
# Out:
#     Year              Datetime    Stage           Stadium        City  \
# 56  1950  25 Jun 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
# 61  1950  29 Jun 1950 - 15:30   Group 3  Durival de Brito   Curitiba
# 65  1950  02 Jul 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 56         Sweden                3                2          Italy
# 61         Sweden                2                2       Paraguay
# 65          Italy                2                0       Paraguay
#
#    Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 56                    36502.0                     2                     1
# 61                     7903.0                     2                     1
# 65                    25811.0                     1                     0
#
#                   Referee             Assistant 1                Assistant 2  \
# 56        LUTZ Jean (SUI)     BERANEK Alois (AUT)        TEJADA Carlos (MEX)
# 61  MITCHELL Robert (SCO)       LEMESIC Leo (YUG)     GARCIA Prudencio (USA)
# 65     ELLIS Arthur (ENG)  GARCIA Prudencio (USA)  DE LA SALLE Charles (FRA)
#
#     RoundID  MatchID Home Team Initials Away Team Initials
# 56      208     1219                SWE                ITA
# 61      208     1228                SWE                PAR
# 65      208     1218                ITA                PAR

# %% [markdown]
# Let's repeat the command above, but this time display **only the attendance column** for the Group 3 games.

# %%
# Your code here
df.loc[ ((df["Stage"] == "Group 3") & (df["Year"] == 1950)), ["Attendance"]]
# Out:
#     Attendance
# 56     36502.0
# 61      7903.0
# 65     25811.0

# %% [markdown]
# Throughout the entire history of the World Cup as recorded in this dataset, **how many home games were played by the Netherlands**?
#
# (Remember that you can use the `len()` built-in function to find the number of rows in a DataFrame.)

# %%
# Your code here
len(df.loc[((df["Away Team Name"] == "Netherlands"))])
# Out:
# 22

# %% [markdown]
# **How many games were played by the Netherlands in total**?

# %%
# Your code here
len(df.loc[((df["Home Team Name"] == "Netherlands") | (df["Away Team Name"] == "Netherlands"))])
# Out:
# 54

# %% [markdown]
# Next, let's try and figure out **how many games the USA played in the 2014 World Cup**.

# %%
# Your code here
len(df.loc[(
    ((df["Home Team Name"] == "USA") | (df["Away Team Name"] == "USA")) &
      (df["Year"] == 2014)      
        )])
# Out:
# 5

# %% [markdown]
# Now, let's try to find out **how many countries participated in the 1986 World Cup**.

# %% [markdown]
# Hint 1: As a first step, create a new dataset that only contains games in that year.
#
# Hint 2: Make sure you don't end up with duplicate country names. Consider using `set()` or `.unique()`.

# %%
# Your code here
year = df.loc[(df["Year"] == 1986), ["Home Team Name", "Away Team Name"]]
#print(year)

#Takes into consideration if one team always played home
teams = set (list(year["Home Team Name"]) + list(year["Away Team Name"]))
len(teams)
# Out:
# 24

# %% [markdown]
# ## Changing Values and Creating New Columns

# %% [markdown]
# In World Cup history, **how many matches had 5 goals or more in total**? Create a column `"Total Goals"` to answer this question.

# %%
# Your code here
df.loc[((df["Home Team Goals"] + df["Away Team Goals"]) >= 5)]
# Out:
#        Year              Datetime        Stage             Stadium  \
# 0    1930.0  13 Jul 1930 - 15:00       Group 1             Pocitos
# 10   1930.0  19 Jul 1930 - 15:00       Group 1  Estadio Centenario
# 15   1930.0  26 Jul 1930 - 14:45   Semi-finals  Estadio Centenario
# 16   1930.0  27 Jul 1930 - 14:45   Semi-finals  Estadio Centenario
# 17   1930.0  30 Jul 1930 - 14:15         Final  Estadio Centenario
# ..      ...                   ...          ...                 ...
# 806  2014.0  23 Jun 2014 - 17:00       Group A    Estadio Nacional
# 810  2014.0  24 Jun 2014 - 16:00       Group C      Arena Pantanal
# 812  2014.0  25 Jun 2014 - 13:00       Group F   Estadio Beira-Rio
# 826  2014.0  08 Jul 2014 - 17:00   Semi-finals    Estadio Mineirao
# 848  2014.0  08 Jul 2014 - 17:00   Semi-finals    Estadio Mineirao
#
#                 City Home Team Name  Home Team Goals  Away Team Goals  \
# 0        Montevideo          France              4.0              1.0
# 10       Montevideo       Argentina              6.0              3.0
# 15       Montevideo       Argentina              6.0              1.0
# 16       Montevideo         Uruguay              6.0              1.0
# 17       Montevideo         Uruguay              4.0              2.0
# ..               ...            ...              ...              ...
# 806        Brasilia        Cameroon              1.0              4.0
# 810          Cuiaba           Japan              1.0              4.0
# 812    Porto Alegre         Nigeria              2.0              3.0
# 826  Belo Horizonte          Brazil              1.0              7.0
# 848  Belo Horizonte          Brazil              1.0              7.0
#
#     Away Team Name Win conditions  Attendance  Half-time Home Goals  \
# 0           Mexico                     4444.0                   3.0
# 10          Mexico                    42100.0                   3.0
# 15             USA                    72886.0                   1.0
# 16      Yugoslavia                    79867.0                   3.0
# 17       Argentina                    68346.0                   1.0
# ..             ...            ...         ...                   ...
# 806         Brazil                    69112.0                   1.0
# 810       Colombia                    40340.0                   1.0
# 812      Argentina                    43285.0                   1.0
# 826        Germany                    58141.0                   0.0
# 848        Germany                    58141.0                   0.0
#
#      Half-time Away Goals                 Referee              Assistant 1  \
# 0                     0.0  LOMBARDI Domingo (URU)    CRISTOPHE Henry (BEL)
# 10                    1.0    SAUCEDO Ulises (BOL)   ALONSO Gualberto (URU)
# 15                    0.0     LANGENUS Jean (BEL)     VALLEJO Gaspar (MEX)
# 16                    1.0     REGO Gilberto (BRA)     SAUCEDO Ulises (BOL)
# 17                    2.0     LANGENUS Jean (BEL)     SAUCEDO Ulises (BOL)
# ..                    ...                     ...                      ...
# 806                   2.0    ERIKSSON Jonas (SWE)  KLASENIUS Mathias (SWE)
# 810                   1.0     PROENCA Pedro (POR)    MIRANDA Bertino (POR)
# 812                   2.0    Nicola RIZZOLI (ITA)    Renato FAVERANI (ITA)
# 826                   5.0   RODRIGUEZ Marco (MEX)  TORRENTERA Marvin (MEX)
# 848                   5.0   RODRIGUEZ Marco (MEX)  TORRENTERA Marvin (MEX)
#
#                     Assistant 2   RoundID      MatchID Home Team Initials  \
# 0           REGO Gilberto (BRA)     201.0       1096.0                FRA
# 10   RADULESCU Constantin (ROU)     201.0       1086.0                ARG
# 15        WARNKEN Alberto (CHI)     202.0       1088.0                ARG
# 16          BALWAY Thomas (FRA)     202.0       1101.0                URU
# 17        CRISTOPHE Henry (BEL)     405.0       1087.0                URU
# ..                          ...       ...          ...                ...
# 806       WARNMARK Daniel (SWE)  255931.0  300186472.0                CMR
# 810            TRIGO Jose (POR)  255931.0  300186457.0                JPN
# 812        Andrea STEFANI (ITA)  255931.0  300186458.0                NGA
# 826       QUINTERO Marcos (MEX)  255955.0  300186474.0                BRA
# 848       QUINTERO Marcos (MEX)  255955.0  300186474.0                BRA
#
#     Away Team Initials
# 0                  MEX
# 10                 MEX
# 15                 USA
# 16                 YUG
# 17                 ARG
# ..                 ...
# 806                BRA
# 810                COL
# 812                ARG
# 826                GER
# 848                GER
#
# [147 rows x 20 columns]

# %% [markdown]
# Now **create a new column `"Half-time Goals"`** in `df` that includes both home and away values.

# %%
# Your code here
df.loc[:, 'Half-Time-Goals'] = (df['Half-time Home Goals'] + df["Half-time Away Goals"])

# %%
# Run this cell without changes to see your new column
print(df.columns)
df
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials',
#        'Half-Time-Goals'],
#       dtype='object')
#                    Year              Datetime                     Stage  \
# 0                1930.0  13 Jul 1930 - 15:00                    Group 1
# 1                1930.0  13 Jul 1930 - 15:00                    Group 4
# 2                1930.0  14 Jul 1930 - 12:45                    Group 2
# 3                1930.0  14 Jul 1930 - 14:50                    Group 3
# 4                1930.0  15 Jul 1930 - 16:00                    Group 1
# ...                 ...                   ...                       ...
# 848              2014.0  08 Jul 2014 - 17:00                Semi-finals
# 849              2014.0  09 Jul 2014 - 17:00                Semi-finals
# 850              2014.0  12 Jul 2014 - 17:00   Play-off for third place
# 851              2014.0  13 Jul 2014 - 16:00                      Final
# Half-Time-Goals     NaN                   NaN                       NaN
#
#                              Stadium             City Home Team Name  \
# 0                            Pocitos      Montevideo          France
# 1                     Parque Central      Montevideo             USA
# 2                     Parque Central      Montevideo      Yugoslavia
# 3                            Pocitos      Montevideo         Romania
# 4                     Parque Central      Montevideo       Argentina
# ...                              ...              ...            ...
# 848                 Estadio Mineirao  Belo Horizonte          Brazil
# 849               Arena de Sao Paulo       Sao Paulo     Netherlands
# 850                 Estadio Nacional        Brasilia          Brazil
# 851              Estadio do Maracana  Rio De Janeiro         Germany
# Half-Time-Goals                  NaN              NaN            NaN
#
#                  Home Team Goals  Away Team Goals Away Team Name  \
# 0                            4.0              1.0         Mexico
# 1                            3.0              0.0        Belgium
# 2                            2.0              1.0         Brazil
# 3                            3.0              1.0           Peru
# 4                            1.0              0.0         France
# ...                          ...              ...            ...
# 848                          1.0              7.0        Germany
# 849                          0.0              0.0      Argentina
# 850                          0.0              3.0    Netherlands
# 851                          1.0              0.0      Argentina
# Half-Time-Goals              NaN              NaN            NaN
#
#                                       Win conditions  ...  \
# 0                                                     ...
# 1                                                     ...
# 2                                                     ...
# 3                                                     ...
# 4                                                     ...
# ...                                              ...  ...
# 848                                                   ...
# 849              Argentina win on penalties (2 - 4)   ...
# 850                                                   ...
# 851                    Germany win after extra time   ...
# Half-Time-Goals                                  NaN  ...
#
#                  Half-time Home Goals  Half-time Away Goals  \
# 0                                 3.0                   0.0
# 1                                 2.0                   0.0
# 2                                 2.0                   0.0
# 3                                 1.0                   0.0
# 4                                 0.0                   0.0
# ...                               ...                   ...
# 848                               0.0                   5.0
# 849                               0.0                   0.0
# 850                               0.0                   2.0
# 851                               0.0                   0.0
# Half-Time-Goals                   NaN                   NaN
#
#                                 Referee               Assistant 1  \
# 0                LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1                     MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2                   TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3                 WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4                   REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
# ...                                 ...                       ...
# 848               RODRIGUEZ Marco (MEX)   TORRENTERA Marvin (MEX)
# 849                  C�neyt �AKIR (TUR)      DURAN Bahattin (TUR)
# 850               HAIMOUDI Djamel (ALG)      ACHIK Redouane (MAR)
# 851                Nicola RIZZOLI (ITA)     Renato FAVERANI (ITA)
# Half-Time-Goals                     NaN                       NaN
#
#                                 Assistant 2   RoundID      MatchID  \
# 0                       REGO Gilberto (BRA)     201.0       1096.0
# 1                     WARNKEN Alberto (CHI)     201.0       1090.0
# 2                       BALWAY Thomas (FRA)     201.0       1093.0
# 3                  MATEUCCI Francisco (URU)     201.0       1098.0
# 4                RADULESCU Constantin (ROU)     201.0       1085.0
# ...                                     ...       ...          ...
# 848                   QUINTERO Marcos (MEX)  255955.0  300186474.0
# 849                       ONGUN Tarik (TUR)  255955.0  300186490.0
# 850                 ETCHIALI Abdelhak (ALG)  255957.0  300186502.0
# 851                    Andrea STEFANI (ITA)  255959.0  300186501.0
# Half-Time-Goals                         NaN       NaN          NaN
#
#                  Home Team Initials Away Team Initials Half-Time-Goals
# 0                               FRA                MEX             3.0
# 1                               USA                BEL             2.0
# 2                               YUG                BRA             2.0
# 3                               ROU                PER             1.0
# 4                               ARG                FRA             0.0
# ...                             ...                ...             ...
# 848                             BRA                GER             5.0
# 849                             NED                ARG             0.0
# 850                             BRA                NED             2.0
# 851                             GER                ARG             0.0
# Half-Time-Goals                 NaN                NaN             NaN
#
# [853 rows x 21 columns]

# %% [markdown]
# Run the code below. You'll notice that for Korea, there are records for both North-Korea (Korea DPR) and South-Korea (Korea Republic).

# %%
# Run this cell without changes

# Display all records containing the string 'Korea'
df.loc[df['Home Team Name'].str.contains('Korea', na=False), 'Home Team Name']
# Out:
# 179         Korea DPR
# 187         Korea DPR
# 374    Korea Republic
# 386    Korea Republic
# 434    Korea Republic
# 444    Korea Republic
# 480    Korea Republic
# 524    Korea Republic
# 593    Korea Republic
# 609    Korea Republic
# 635    Korea Republic
# 642    Korea Republic
# 655    Korea Republic
# 710    Korea Republic
# 753         Korea DPR
# 802    Korea Republic
# 818    Korea Republic
# Name: Home Team Name, dtype: object

# %% [markdown]
# Imagine that, for some reason, we simply want Korea listed as one entry, so we want to replace every "Home Team Name" and "Away Team Name" entry that contains "Korea" to simply "Korea". In the same way, we want to change the columns "Home Team Initials" and "Away Team Initials" to NSK (North & South Korea) instead of "KOR" and "PRK".

# %%
# Update the 'Home Team Name' and 'Home Team Initials' columns 
df.loc[df['Home Team Name'].str.contains('Korea', na=False), 'Home Team Name'] = "Korea"
df.loc[df['Away Team Name'].str.contains('Korea', na=False), 'Away Team Name'] = "Korea"

# %% [markdown]
# Make sure to verify your answer!

# %%
# Check the updated columns
df.loc[(df['Home Team Name'].str.contains('Korea', na=False) | df['Away Team Name'].str.contains('Korea', na=False))]
# Out:
#        Year              Datetime           Stage  \
# 80   1954.0  17 Jun 1954 - 18:00          Group 2
# 88   1954.0  20 Jun 1954 - 17:00          Group 2
# 171  1966.0  12 Jul 1966 - 19:30          Group 4
# 179  1966.0  15 Jul 1966 - 19:30          Group 4
# 187  1966.0  19 Jul 1966 - 19:30          Group 4
# 195  1966.0  23 Jul 1966 - 15:00   Quarter-finals
# 364  1986.0  02 Jun 1986 - 12:00          Group A
# 374  1986.0  05 Jun 1986 - 16:00          Group A
# 386  1986.0  10 Jun 1986 - 12:00          Group A
# 421  1990.0  12 Jun 1990 - 17:00          Group E
# 434  1990.0  17 Jun 1990 - 21:00          Group E
# 444  1990.0  21 Jun 1990 - 17:00          Group E
# 464  1994.0  17 Jun 1994 - 19:30          Group C
# 480  1994.0  23 Jun 1994 - 19:30          Group C
# 490  1994.0  27 Jun 1994 - 16:00          Group C
# 524  1998.0  13 Jun 1998 - 17:30          Group E
# 542  1998.0  20 Jun 1998 - 21:00          Group E
# 556  1998.0  25 Jun 1998 - 16:00          Group E
# 593  2002.0  04 Jun 2002 - 20:30          Group D
# 609  2002.0  10 Jun 2002 - 15:30          Group D
# 625  2002.0  14 Jun 2002 - 20:30          Group D
# 635  2002.0  18 Jun 2002 - 20:30      Round of 16
# 639  2002.0  22 Jun 2002 - 15:30   Quarter-finals
# 640  2002.0  25 Jun 2002 - 20:30      Semi-finals
# 642  2002.0  29 Jun 2002 - 20:00      Third place
# 655  2006.0  13 Jun 2006 - 15:00          Group G
# 672  2006.0  18 Jun 2006 - 21:00          Group G
# 691  2006.0  23 Jun 2006 - 21:00          Group G
# 710  2010.0  12 Jun 2010 - 13:30          Group B
# 721  2010.0  15 Jun 2010 - 20:30          Group G
# 725  2010.0  17 Jun 2010 - 13:30          Group B
# 737  2010.0  21 Jun 2010 - 13:30          Group G
# 742  2010.0  22 Jun 2010 - 20:30          Group B
# 753  2010.0  25 Jun 2010 - 16:00          Group G
# 756  2010.0  26 Jun 2010 - 16:00      Round of 16
# 788  2014.0  17 Jun 2014 - 18:00          Group H
# 802  2014.0  22 Jun 2014 - 16:00          Group H
# 818  2014.0  26 Jun 2014 - 17:00          Group H
#
#                                Stadium                                City  \
# 80                            Hardturm                             Zurich
# 88                          Charmilles                             Geneva
# 171                      Ayresome Park                      Middlesbrough
# 179                      Ayresome Park                      Middlesbrough
# 187                      Ayresome Park                      Middlesbrough
# 195                      Goodison Park                          Liverpool
# 364     Estadio Ol�mpico Universitario                        Mexico City
# 374     Estadio Ol�mpico Universitario                        Mexico City
# 386                         Cuauhtemoc                             Puebla
# 421             Marc Antonio Bentegodi                             Verona
# 434                        Dacia Arena                              Udine
# 444                             Friuli                              Udine
# 464                        Cotton Bowl                             Dallas
# 480                    Foxboro Stadium                             Boston
# 490                        Cotton Bowl                             Dallas
# 524                   Stade de Gerland                               Lyon
# 542                    Stade V�lodrome                         Marseilles
# 556                   Parc des Princes                              Paris
# 593           Busan Asiad Main Stadium                              Busan
# 609            Daegu World Cup Stadium                              Daegu
# 625           Incheon Football Stadium                            Incheon
# 635          Daejeon World Cup Stadium                            Daejeon
# 639          Gwangju World Cup Stadium                            Gwangju
# 640            Seoul World Cup Stadium                              Seoul
# 642            Daegu World Cup Stadium                              Daegu
# 655  FIFA World Cup Stadium, Frankfurt                     Frankfurt/Main
# 672                     Zentralstadion                            Leipzig
# 691    FIFA World Cup Stadium, Hanover                            Hanover
# 710             Port Elizabeth Stadium  Nelson Mandela Bay/Port Elizabeth
# 721                 Ellis Park Stadium                       Johannesburg
# 725                Soccer City Stadium                       Johannesburg
# 737                  Cape Town Stadium                          Cape Town
# 742                     Durban Stadium                             Durban
# 753                   Mbombela Stadium                          Nelspruit
# 756             Port Elizabeth Stadium  Nelson Mandela Bay/Port Elizabeth
# 788                     Arena Pantanal                             Cuiaba
# 802                  Estadio Beira-Rio                       Porto Alegre
# 818                 Arena de Sao Paulo                          Sao Paulo
#
#     Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 80         Hungary              9.0              0.0          Korea
# 88          Turkey              7.0              0.0          Korea
# 171   Soviet Union              3.0              0.0          Korea
# 179          Korea              1.0              1.0          Chile
# 187          Korea              1.0              0.0          Italy
# 195       Portugal              5.0              3.0          Korea
# 364      Argentina              3.0              1.0          Korea
# 374          Korea              1.0              1.0       Bulgaria
# 386          Korea              2.0              3.0          Italy
# 421        Belgium              2.0              0.0          Korea
# 434          Korea              1.0              3.0          Spain
# 444          Korea              0.0              1.0        Uruguay
# 464          Spain              2.0              2.0          Korea
# 480          Korea              0.0              0.0        Bolivia
# 490        Germany              3.0              2.0          Korea
# 524          Korea              1.0              3.0         Mexico
# 542    Netherlands              5.0              0.0          Korea
# 556        Belgium              1.0              1.0          Korea
# 593          Korea              2.0              0.0         Poland
# 609          Korea              1.0              1.0            USA
# 625       Portugal              0.0              1.0          Korea
# 635          Korea              2.0              1.0          Italy
# 639          Spain              0.0              0.0          Korea
# 640        Germany              1.0              0.0          Korea
# 642          Korea              2.0              3.0         Turkey
# 655          Korea              2.0              1.0           Togo
# 672         France              1.0              1.0          Korea
# 691    Switzerland              2.0              0.0          Korea
# 710          Korea              2.0              0.0         Greece
# 721         Brazil              2.0              1.0          Korea
# 725      Argentina              4.0              1.0          Korea
# 737       Portugal              7.0              0.0          Korea
# 742        Nigeria              2.0              2.0          Korea
# 753          Korea              0.0              3.0  C�te d'Ivoire
# 756        Uruguay              2.0              1.0          Korea
# 788         Russia              1.0              1.0          Korea
# 802          Korea              2.0              4.0        Algeria
# 818          Korea              0.0              1.0        Belgium
#
#                                Win conditions  ...  Half-time Home Goals  \
# 80                                             ...                   4.0
# 88                                             ...                   4.0
# 171                                            ...                   2.0
# 179                                            ...                   0.0
# 187                                            ...                   1.0
# 195                                            ...                   2.0
# 364                                            ...                   2.0
# 374                                            ...                   0.0
# 386                                            ...                   0.0
# 421                                            ...                   0.0
# 434                                            ...                   1.0
# 444                                            ...                   0.0
# 464                                            ...                   0.0
# 480                                            ...                   0.0
# 490                                            ...                   3.0
# 524                                            ...                   1.0
# 542                                            ...                   2.0
# 556                                            ...                   1.0
# 593                                            ...                   1.0
# 609                                            ...                   0.0
# 625                                            ...                   0.0
# 635                       Win on Golden Goal   ...                   0.0
# 639  Korea Republic win on penalties (3 - 5)   ...                   0.0
# 640                                            ...                   0.0
# 642                                            ...                   1.0
# 655                                            ...                   0.0
# 672                                            ...                   1.0
# 691                                            ...                   1.0
# 710                                            ...                   1.0
# 721                                            ...                   0.0
# 725                                            ...                   2.0
# 737                                            ...                   1.0
# 742                                            ...                   1.0
# 753                                            ...                   0.0
# 756                                            ...                   1.0
# 788                                            ...                   0.0
# 802                                            ...                   0.0
# 818                                            ...                   0.0
#
#      Half-time Away Goals                           Referee  \
# 80                    0.0            VINCENTI Raymond (FRA)
# 88                    0.0              MARINO Esteban (URU)
# 171                   0.0            GARDEAZABAL Juan (ESP)
# 179                   1.0          KANDIL Aly Hussein (EGY)
# 187                   0.0             SCHWINTE Pierre (FRA)
# 195                   3.0          ASHKENAZI Menachem (ISR)
# 364                   0.0  SANCHEZ ARMINIO Victoriano (ESP)
# 374                   1.0     AL SHANAR Fallaj Khuzam (KSA)
# 386                   1.0                 SOCHA David (USA)
# 421                   0.0               MAURO Vincent (USA)
# 434                   1.0    JACOME GUERRERO Elias V. (ECU)
# 444                   0.0               LANESE Tullio (ITA)
# 464                   0.0             MIKKELSEN Peter (DEN)
# 480                   0.0              MOTTRAM Leslie (SCO)
# 490                   0.0                QUINIOU Joel (FRA)
# 524                   0.0                BENKO Gunter (AUT)
# 542                   0.0              WOJCIK Ryszard (POL)
# 556                   0.0              REZENDE Marcio (BRA)
# 593                   0.0                  RUIZ Oscar (COL)
# 609                   1.0                   MEIER Urs (SUI)
# 625                   0.0               SANCHEZ Angel (ARG)
# 635                   0.0                MORENO Byron (ECU)
# 639                   0.0           EL GHANDOUR Gamal (EGY)
# 640                   0.0                   MEIER Urs (SUI)
# 642                   3.0                   MANE Saad (KUW)
# 655                   1.0                 POLL Graham (ENG)
# 672                   0.0            ARCHUNDIA Benito (MEX)
# 691                   0.0            ELIZONDO Horacio (ARG)
# 710                   0.0              HESTER Michael (NZL)
# 721                   0.0               KASSAI Viktor (HUN)
# 725                   1.0          DE BLEECKERE Frank (BEL)
# 737                   0.0                  POZO Pablo (CHI)
# 742                   1.0        Oleg�rio BENQUEREN�A (POR)
# 753                   2.0    Alberto UNDIANO MALLENCO (ESP)
# 756                   0.0              Wolfgang STARK (GER)
# 788                   0.0               PITANA Nestor (ARG)
# 802                   3.0               ROLDAN Wilmar (COL)
# 818                   0.0                Ben WILLIAMS (AUS)
#
#                             Assistant 1               Assistant 2     RoundID  \
# 80              VON GUNTER Albert (SUI)        STEINER Carl (AUT)       211.0
# 88             ORLANDINI Vincenzo (ITA)  SCHONHOLZER Ernest (SUI)       211.0
# 171            KANDIL Aly Hussein (EGY)    DIENST Gottfried (SUI)       238.0
# 179              CRAWFORD William (SCO)          FINNEY Jim (ENG)       238.0
# 187                    ADAIR John (NIR)         TAYLOR John (ENG)       238.0
# 195                   GALBA Karol (TCH)     SCHWINTE Pierre (FRA)       239.0
# 364          GONZALEZ ROA Gabriel (PAR)  DIAZ PALACIO Jesus (COL)       308.0
# 374                     IGNA Ioan (ROU)      BUTENKO Valeri (RUS)       308.0
# 386                 URREA Joaquin (MEX)     AL SHARIF Jamal (SYR)       308.0
# 421                   SNODDY Alan (NIR)     COURTNEY George (ENG)       322.0
# 434               MAGNI Pierluigi (ITA)        LOUSTAU Juan (ARG)       322.0
# 444           DIRAMBA Jean Fidele (GAB)         JOUINI Neji (TUN)       322.0
# 464  CHRISTENSEN Carl-Johan Meyer (DEN)         PEARSON Roy (ENG)       337.0
# 480                   MATTHYS Luc (BEL)     EVERSTIG Mikael (SWE)       337.0
# 490               IVANOV Valentin (RUS)  HASSAN Abdel-Magid (EGY)       337.0
# 524                   FRED Lencie (VAN)     SCHNEIDER Erich (GER)      1014.0
# 542               POCIEGIEL Jacek (POL)        DUPANOV Yuri (BLR)      1014.0
# 556                 PINTO Arnaldo (BRA)   ARANGO Jorge Luis (COL)      1014.0
# 593                  DORIRI Elise (VAN)       LINDBERG Leif (SWE)  43950100.0
# 609                 BEREUTER Egon (AUT)       TOMUSANGE Ali (UGA)  43950100.0
# 625                  ALTRAIFI Ali (KSA)      SZEKELY Ferenc (HUN)  43950100.0
# 635               RATTALINO Jorge (ARG)      SZEKELY Ferenc (HUN)  43950200.0
# 639                 TOMUSANGE Ali (UGA)   RAGOONATH Michael (TRI)  43950300.0
# 640              ARNAULT Frederic (FRA)         AMLER Evzen (CZE)  43950400.0
# 642                  ALTRAIFI Ali (KSA)      VERGARA Hector (CAN)  43950500.0
# 655                  SHARP Philip (ENG)        TURNER Glenn (ENG)  97410100.0
# 672                  RAMIREZ Jose (MEX)      VERGARA Hector (CAN)  97410100.0
# 691                  GARCIA Dario (ARG)       OTERO Rodolfo (ARG)  97410100.0
# 710             HINTZ Jan Hendrik (NZL)     MAKASINI Tevita (TGA)    249722.0
# 721                    EROS Gabor (HUN)         VAMOS Tibor (HUN)    249722.0
# 725                 HERMANS Peter (BEL)      VROMANS Walter (BEL)    249722.0
# 737             BASUALTO Patricio (CHI)   MONDRIA Francisco (CHI)    249722.0
# 742                 CARDINAL Jose (POR)     MIRANDA Bertino (POR)    249722.0
# 753               MARTINEZ Fermin (ESP)          YUSTE Juan (ESP)    249722.0
# 756            SALVER Jan-Hendrik (GER)         PICKEL Mike (GER)    249717.0
# 788                MAIDANA Hernan (ARG)  BELATTI Juan Pablo (ARG)    255931.0
# 802                  DIAZ Eduardo (COL)   LESCANO Christian (ECU)    255931.0
# 818                 CREAM Matthew (AUS)          ANAZ Hakan (AUS)    255931.0
#
#          MatchID  Home Team Initials Away Team Initials Half-Time-Goals
# 80        1294.0                 HUN                KOR             4.0
# 88        1304.0                 TUR                KOR             4.0
# 171       1710.0                 URS                PRK             2.0
# 179       1609.0                 PRK                CHI             1.0
# 187       1679.0                 PRK                ITA             1.0
# 195       1702.0                 POR                PRK             5.0
# 364        395.0                 ARG                KOR             2.0
# 374        460.0                 KOR                BUL             1.0
# 386        643.0                 KOR                ITA             1.0
# 421         57.0                 BEL                KOR             0.0
# 434        175.0                 KOR                ESP             2.0
# 444        290.0                 KOR                URU             0.0
# 464       3050.0                 ESP                KOR             0.0
# 480       3065.0                 KOR                BOL             0.0
# 490       3076.0                 GER                KOR             3.0
# 524       8732.0                 KOR                MEX             1.0
# 542       8749.0                 NED                KOR             2.0
# 556       8765.0                 BEL                KOR             1.0
# 593   43950014.0                 KOR                POL             1.0
# 609   43950030.0                 KOR                USA             1.0
# 625   43950047.0                 POR                KOR             0.0
# 635   43950056.0                 KOR                ITA             0.0
# 639   43950059.0                 ESP                KOR             0.0
# 640   43950061.0                 GER                KOR             0.0
# 642   43950063.0                 KOR                TUR             4.0
# 655   97410014.0                 KOR                TOG             1.0
# 672   97410029.0                 FRA                KOR             1.0
# 691   97410046.0                 SUI                KOR             1.0
# 710  300061459.0                 KOR                GRE             1.0
# 721  300061490.0                 BRA                PRK             0.0
# 725  300061458.0                 ARG                KOR             3.0
# 737  300061487.0                 POR                PRK             1.0
# 742  300111115.0                 NGA                KOR             2.0
# 753  300061486.0                 PRK                CIV             2.0
# 756  300061504.0                 URU                KOR             1.0
# 788  300186499.0                 RUS                KOR             0.0
# 802  300186495.0                 KOR                ALG             3.0
# 818  300186480.0                 KOR                BEL             0.0
#
# [38 rows x 21 columns]

# %% [markdown]
# ## Summary
#
# In this lab, you practiced accessing data within Pandas!
